# %%
import numpy as np
import pandas as pd
import datetime as dt

# %%
bint_df = pd.read_csv(r"C:\Users\kurst\OneDrive\BINT.csv", parse_dates=[['GRADDATE','PROGRAMSTART']])

# %%
bint_df
# Out:
#       PROGRAMSTART_GRADDATE  STUID         DOB GENDER  ETHNICITYID ETHNICITY  \
# 0     16/08/2004 11/06/2006      1  20/03/1983      F          8.0    Creole
# 1     16/08/2004 11/06/2006      1  20/03/1983      F          8.0    Creole
# 2     16/08/2004 11/06/2006      1  20/03/1983      F          8.0    Creole
# 3     16/08/2004 11/06/2006      1  20/03/1983      F          8.0    Creole
# 4     16/08/2004 11/06/2006      1  20/03/1983      F          8.0    Creole
# ...                     ...    ...         ...    ...          ...       ...
# 8439         19/08/2013 nan   8423  13/06/1978      F          8.0    Creole
# 8440         19/08/2013 nan   8423  13/06/1978      F          8.0    Creole
# 8441         19/08/2013 nan   8423  13/06/1978      F          8.0    Creole
# 8442         19/08/2013 nan   8423  13/06/1978      F          8.0    Creole
# 8443                nan nan      1         NaN    NaN          NaN       NaN
#
# ...

# %%
clean_bint_df=bint_df.drop(['ETHNICITYID', 'CITYID', 'DISTRICTID', 'DEGREEID','FEEDERID','DEGREE', 'BREAK', 'PROGRAM', 'CODE', 'COMMENTS'], axis=1)

# %%
clean_bint_df
# Out:
#       STUID         DOB GENDER ETHNICITY         CITY DISTRICT  \
# 0         1  20/03/1983      F    Creole  BELIZE CITY   BELIZE
# 1         1  20/03/1983      F    Creole  BELIZE CITY   BELIZE
# 2         1  20/03/1983      F    Creole  BELIZE CITY   BELIZE
# 3         1  20/03/1983      F    Creole  BELIZE CITY   BELIZE
# 4         1  20/03/1983      F    Creole  BELIZE CITY   BELIZE
# ...     ...         ...    ...       ...          ...      ...
# 8439   8423  13/06/1978      F    Creole  BELIZE CITY   BELIZE
# 8440   8423  13/06/1978      F    Creole  BELIZE CITY   BELIZE
# 8441   8423  13/06/1978      F    Creole  BELIZE CITY   BELIZE
# 8442   8423  13/06/1978      F    Creole  BELIZE CITY   BELIZE
# 8443      1         NaN    NaN       NaN          NaN      NaN
#
#                     FEEDER PROGRAMSTART PROGRAMSTATUS    GRADDATE  ...  \
# 0     UNIVERSITY OF BELIZE   16/08/2004     Graduated  11/06/2006  ...
# ...

# %%
clean_bint_df.drop([8443], axis=0)
# Out:
#       STUID         DOB GENDER ETHNICITY         CITY DISTRICT  \
# 0         1  20/03/1983      F    Creole  BELIZE CITY   BELIZE
# 1         1  20/03/1983      F    Creole  BELIZE CITY   BELIZE
# 2         1  20/03/1983      F    Creole  BELIZE CITY   BELIZE
# 3         1  20/03/1983      F    Creole  BELIZE CITY   BELIZE
# 4         1  20/03/1983      F    Creole  BELIZE CITY   BELIZE
# ...     ...         ...    ...       ...          ...      ...
# 8438   8423  13/06/1978      F    Creole  BELIZE CITY   BELIZE
# 8439   8423  13/06/1978      F    Creole  BELIZE CITY   BELIZE
# 8440   8423  13/06/1978      F    Creole  BELIZE CITY   BELIZE
# 8441   8423  13/06/1978      F    Creole  BELIZE CITY   BELIZE
# 8442   8423  13/06/1978      F    Creole  BELIZE CITY   BELIZE
#
#                     FEEDER PROGRAMSTART  DEGREEID PROGRAMSTATUS  ...  \
# 0     UNIVERSITY OF BELIZE   16/08/2004      13.0     Graduated  ...
# ...

# %%
clean_duplicates_bint_df = clean_bint_df.drop_duplicates(subset="STUID", keep='first', ignore_index=False)

# %%
clean_duplicates_bint_df
# Out:
#       STUID         DOB GENDER  ETHNICITY           CITY     DISTRICT  \
# 0         1  20/03/1983      F     Creole    BELIZE CITY       BELIZE
# 18       19  27/12/1980      F    Mestizo    ORANGE WALK  ORANGE WALK
# 55       56  30/10/1981      M    Mestizo  BELMOPAN CITY         CAYO
# 104     105  31/05/1976      M    Unknown           CAYO       BELIZE
# 108     109  04/08/1981      M    Unknown           CAYO       BELIZE
# ...     ...         ...    ...        ...            ...          ...
# 8321   8322  26/11/1973      M      Other  BELMOPAN CITY         CAYO
# 8339   8340  09/07/1979      M    Mestizo    BELIZE CITY       BELIZE
# 8367   8368  24/02/1981      F    Unknown    BELIZE CITY       BELIZE
# 8393   8394  27/01/1979      M  Caucasian  BELMOPAN CITY         CAYO
# 8422   8423  13/06/1978      F     Creole    BELIZE CITY       BELIZE
#
#                             FEEDER PROGRAMSTART PROGRAMSTATUS    GRADDATE  \
# ...

# %%
clean_duplicates_bint_df.groupby("GENDER")["GENDER"].count().sort_values(ascending=False).plot.bar();

# %%
clean_duplicates_bint_df.groupby("ETHNICITY")["ETHNICITY"].count().sort_values(ascending=False).plot.bar();

# %%
clean_duplicates_bint_df.groupby("FEEDER")["FEEDER"].count().sort_values(ascending=False)
# Out:
# FEEDER
# UNIVERSITY OF BELIZE                  209
# ST. JOHN'S COLLEGE JUNIOR COLLEGE      65
# SACRED HEART JUNIOR COLLEGE            26
# ESCUELA MEXICO JR COLLEGE              14
# COROZAL JUNIOR COLLEGE                 12
# MUFFLES JUNIOR COLLEGE                 10
#  WESLEY JUNIOR COLLEGE                 10
# BELMOPAN COMPREHENSIVE SCHOOL           9
# FOREIGN                                 8
# *UNKNOWN                                8
# INDEPENDENCE JUNIOR COLLEGE             7
#  STANN CREEK ECUMENICAL HIGH SC         6
# SACRED HEART COLLEGE                    5
# STANN CREEK ECUMENICAL JR. COLLEGE      5
# BELMOPAN JUNIOR COLLEGE                 4
# BELIZE ADVENTIST JUNIOR COLLEGE         4
# BELIZE ADVENTIST COLLEGE                3
# BELIZE TECHNICAL COLLEGE                3
# UNIVERSITY COLLEGE OF BELIZE            3
# BELIZE CHRISTIAN ACADEMY                3
# ST. CATHERINE ACADEMY                   3
# EDWARD P. YORKE                         2
# ...

# %%
clean_duplicates_bint_df.groupby("CITY")["CITY"].count().sort_values(ascending=False)
# Out:
# CITY
# BELIZE CITY                 89
# BELMOPAN CITY               86
# -                           66
# BELMOPAN                    24
# SAN IGNACIO                 18
# DANGRIGA TOWN               16
# CAYO                        14
# ORANGE WALK                 14
# ORANGE WALK TOWN            13
# BENQUE VIEJO DEL CARMEN     11
# COROZAL TOWN                11
# BELIZE                       8
# STANN CREEK                  8
# SAN IGNACIO TOWN             4
# LADYVILLE VILLAGE            3
# ORANGE WALK DISTRICT         3
# SANTA ELENA                  2
# ROARING CREEK VILLAGE        2
# SAN NARCISO VILLAGE          2
# PUNTA GORDA                  2
# BULLET TREE FALLS            2
# NIGERIA                      2
# CAYO DISTRICT                2
# BURRELL BOOM VILLAGE         2
# Belize                       2
# COROZAL                      2
# COROZAL DISTRICT             2
# SAN PEDRO                    1
# SAN ROMAN VILLAGE            1
# SANDHILL VILLAGE             1
# ...

# %%
clean_duplicates_bint_df.groupby("DISTRICT")["DISTRICT"].count().sort_values(ascending=False)
# Out:
# DISTRICT
# CAYO           173
# BELIZE         152
# ORANGE WALK     40
# STANN CREEK     34
# COROZAL         24
# TOLEDO           9
# NIGERIA          2
# 465              1
# Name: DISTRICT, dtype: int64

# %%
clean_bint_df.groupby("COURSECODE")["COURSECODE"].count().sort_values(ascending=False)
# Out:
# COURSECODE
# MATH3251    260
# CMPS3151    251
# MATH3151    249
# CMPS3111    234
# CMPS3252    226
#            ...
# CMPS326       1
# ECON101       1
# ECON1014      1
# ECON2054      1
# STSK101       1
# Name: COURSECODE, Length: 241, dtype: int64

# %%
clean_duplicates_bint_df.describe(include="all")
# Out:
# C:\Users\kurst\AppData\Local\Temp\ipykernel_24424\2319746992.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   clean_duplicates_bint_df.describe(include="all")
#               STUID         DOB GENDER ETHNICITY         CITY DISTRICT  \
# count    436.000000         436    436       436          431      435
# unique          NaN         426      2        10           48        8
# top             NaN  12/04/1994      M   Mestizo  BELIZE CITY     CAYO
# freq            NaN           2    339       175           89      173
# first           NaN         NaN    NaN       NaN          NaN      NaN
# last            NaN         NaN    NaN       NaN          NaN      NaN
# mean    4300.561927         NaN    NaN       NaN          NaN      NaN
# ...

# %%
clean_duplicates_bint_df.groupby("PROGRAMSTATUS")["PROGRAMSTATUS"].count().sort_values(ascending=False)
# Out:
# PROGRAMSTATUS
# Graduated      232
# Terminated      90
# In Process      61
# Dropped         47
# Transferred      5
# terminated       1
# Name: PROGRAMSTATUS, dtype: int64

# %%
clean_bint_df.groupby("COURSEGRADE")["COURSEGRADE"].count()
# Out:
# COURSEGRADE
# A      909
# A-    1304
# AU      18
# B     1397
# B+    1450
# C      812
# C+     978
# D      232
# D+     243
# F      444
# NG      39
# NR       5
# P       26
# RE      81
# W      108
# WF     151
# WP      58
# Name: COURSEGRADE, dtype: int64

# %%
clean_duplicates_bint_df["CGPA"].max()
# Out:
# 3.94

# %%
clean_duplicates_bint_df["CGPA"].mean()
# Out:
# 2.892365339578454

# %%
clean_duplicates_bint_df['PROGRAMSTART']=pd.to_datetime(clean_duplicates_bint_df['PROGRAMSTART'])
# Out:
# C:\Users\kurst\AppData\Local\Temp\ipykernel_24424\1764929238.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   clean_duplicates_bint_df['PROGRAMSTART']=pd.to_datetime(clean_duplicates_bint_df['PROGRAMSTART'])
# C:\Users\kurst\AppData\Local\Temp\ipykernel_24424\1764929238.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_duplicates_bint_df['PROGRAMSTART']=pd.to_datetime(clean_duplicates_bint_df['PROGRAMSTART'])

# %%
clean_duplicates_bint_df["PROGRAMSTART"].mean().strftime('%Y')
# Out:
# '2012'

# %%
clean_duplicates_bint_df["GRADDATE"].dropna(axis=0).mean().strftime('%Y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\nanops.py:1630, in _ensure_numeric(x)
#    1629 try:
# -> 1630     x = float(x)
#    1631 except (TypeError, ValueError):
#    1632     # e.g. "1+1j" or "foo"
#
# ValueError: could not convert string to float: '...'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\nanops.py:1634, in _ensure_numeric(x)
#    1633 try:
# -> 1634     x = complex(x)
#    1635 except ValueError as err:
#    1636     # e.g. "foo"
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[204], line 1
# ...

# %%
clean_duplicates_bint_df.groupby("GRADDATE",pd.TimeGrouper(freq="1Y")).mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[199], line 1
# ----> 1 clean_duplicates_bint_df.groupby("GRADDATE",pd.TimeGrouper(freq="1Y")).mean()
#
# File ~\anaconda3\lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'TimeGrouper'
